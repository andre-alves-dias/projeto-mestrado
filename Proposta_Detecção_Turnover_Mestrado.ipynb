# %% [markdown]
# <a href="https://colab.research.google.com/github/andre-alves-dias/projeto-mestrado/blob/main/Proposta_Detec%C3%A7%C3%A3o_Turnover_Mestrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Metodologia da pesquisa
#
# ![Metodologia - Fluxograma.png](data:image/png;base64,...)

# %% [markdown]
# #Importação de Dataset

# %% [markdown]
# ## 1- Base de Dados HR Comma sep

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/tanlitung388/Python-DataScienceAmplify/master/HR_comma_sep.csv')
print(df.shape)
df.head()

df.rename(columns={'left':'class'}, inplace=True)

tutor='class'
# Out:
# (14999, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   work_accident          14999 non-null  int64
#  6   class                  14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ##2- Base de dados IBM Turnover
#
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset

# %%
# !gdown --fuzzy https://drive.google.com/file/d/10c1fEpX7KvcWAOYJLANgdhkbUg9JkiSz/view?usp=sharing -O IBM.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10c1fEpX7KvcWAOYJLANgdhkbUg9JkiSz
# To: /content/IBM.csv
# 100% 228k/228k [00:00<00:00, 122MB/s]

# %%
import pandas as pd
df = pd.read_csv('IBM.csv')
print(df.shape)
df.head()

df.rename(columns={'Attrition':'class'}, inplace=True)

tutor='class'
# Out:
# (1470, 35)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   class                     1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ##3- Base de dados Turnover
#
# https://www.kaggle.com/datasets/davinwijaya/employee-turnover

# %%
# !gdown --fuzzy https://drive.google.com/file/d/10pz-RkRH-TJvvm542YGVkI0lupGjJWC5/view?usp=sharing -O Turnover.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10pz-RkRH-TJvvm542YGVkI0lupGjJWC5
# To: /content/Turnover.csv
# 100% 83.2k/83.2k [00:00<00:00, 80.3MB/s]

# %%
import pandas as pd
df = pd.read_csv('Turnover.csv', encoding = 'ISO-8859-1')
print(df.shape)
df.head()

df.rename(columns={'event':'class'}, inplace=True)

tutor='class'
# Out:
# (1129, 16)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   stag          1129 non-null   float64
#  1   class         1129 non-null   int64
#  2   gender        1129 non-null   object
#  3   age           1129 non-null   float64
#  4   industry      1129 non-null   object
#  5   profession    1129 non-null   object
#  6   traffic       1129 non-null   object
#  7   coach         1129 non-null   object
#  8   head_gender   1129 non-null   object
#  9   greywage      1129 non-null   object
#  10  way           1129 non-null   object
#  11  extraversion  1129 non-null   float64
#  12  independ      1129 non-null   float64
#  13  selfcontrol   1129 non-null   float64
#  14  anxiety       1129 non-null   float64
#  15  novator       1129 non-null   float64
# dtypes: float64(7), int64(1), object(8)
# memory usage: 141.2+ KB

# %% [markdown]
# ##4- Base de dados Attrition
#
# https://www.kaggle.com/datasets/HRAnalyticRepository/employee-attrition-data

# %%
# !gdown --fuzzy https://drive.google.com/file/d/11Xdm3BY3g2u5Fl_tOKdGCbJNanF5R3Pc/view?usp=sharing -O Attrition.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11Xdm3BY3g2u5Fl_tOKdGCbJNanF5R3Pc
# To: /content/Attrition.csv
# 100% 7.32M/7.32M [00:00<00:00, 28.3MB/s]

# %%
import pandas as pd
df = pd.read_csv('Attrition.csv')
print(df.shape)
df.sample()

df.rename(columns={'STATUS':'class'}, inplace=True)


tutor='class'
# Out:
# (49653, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           49653 non-null  int64
#  1   recorddate_key       49653 non-null  object
#  2   birthdate_key        49653 non-null  object
#  3   orighiredate_key     49653 non-null  object
#  4   terminationdate_key  49653 non-null  object
#  5   age                  49653 non-null  int64
#  6   length_of_service    49653 non-null  int64
#  7   city_name            49653 non-null  object
#  8   department_name      49653 non-null  object
#  9   job_title            49653 non-null  object
#  10  store_name           49653 non-null  int64
#  11  gender_short         49653 non-null  object
#  12  gender_full          49653 non-null  object
#  13  termreason_desc      49653 non-null  object
#  14  termtype_desc        49653 non-null  object
# ...

# %% [markdown]
# # Aplicação do método factorize

# %%
df = df.copy()
tipos = {}
for col in df:
    if df[col].dtype == 'object':
        valores, codigos = pd.factorize(df[col],sort=True)
        tipos[col] = codigos
        df[col] = valores
df = df.fillna(-1)
display(tipos)
df.head()
# Out:
# {'department': Index(['IT', 'RandD', 'accounting', 'hr', 'management', 'marketing',
#         'product_mng', 'sales', 'support', 'technical'],
#        dtype='object'),
#  'salary': Index(['high', 'low', 'medium'], dtype='object')}
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  work_accident  class  promotion_last_5years  \
# 0                   3              0      1                      0
# 1                   6              0      1                      0
# 2                   4              0      1                      0
# ...

# %%
# !pip install imbalanced-learn

# %%
X = df.drop(labels=[tutor],axis=1)
y = df[tutor]

# %% [markdown]
# # Análise dos dados

# %% [markdown]
# ###Matriz de correlação do dataset inteiro

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crie o mapa de correlação
correlation = abs(df.drop([tutor],axis=1)).corr()

# Plote o mapa de correlação
plt.figure(figsize=(15, 15))
sns.heatmap(correlation, annot=True, cmap="Blues")
plt.title("Mapa de correlação das características")
plt.savefig( "mapa_correlacao.pdf", format="pdf", bbox_inches="tight")
plt.show()

# Salve o mapa de correlação em PDF

# %% [markdown]
# ##Aplicação do Método SelectKBest

# %%
X = df.drop(columns=[tutor])
y = df[tutor].values

# %% [markdown]
# https://stackoverflow.com/questions/39839112/the-easiest-way-for-getting-feature-names-after-running-selectkbest-in-scikit-le

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif, chi2
#Suppose, we select 5 features with top 5 Fisher scores
selector = SelectKBest(score_func=chi2, k=5)
#New dataframe with the selected features for later use in the classifier. fit() method works too, if you want only the feature names and their corresponding scores
X_new = selector.fit_transform(X, y)
names = X.columns.values[selector.get_support()]
scores = selector.scores_[selector.get_support()]
names_scores = list(zip(names, scores))
ns_df = pd.DataFrame(data = names_scores, columns=['Feat_names', 'F_Scores'])
#Sort the dataframe for better visualization
ns_df_sorted = ns_df.sort_values(['F_Scores', 'Feat_names'], ascending = [False, True])
print(ns_df_sorted)
# Out:
#               Feat_names    F_Scores
# 1   average_montly_hours  945.588933
# 3          work_accident  306.737710
# 0     satisfaction_level  228.193183
# 2     time_spend_company  191.708547
# 4  promotion_last_5years   56.044865

# %%
new_df=df[names].join(df[tutor])
new_df.head()
# Out:
#    satisfaction_level  average_montly_hours  time_spend_company  \
# 0                0.38                   157                   3
# 1                0.80                   262                   6
# 2                0.11                   272                   4
# 3                0.72                   223                   5
# 4                0.37                   159                   3
#
#    work_accident  promotion_last_5years  class
# 0              0                      0      1
# 1              0                      0      1
# 2              0                      0      1
# 3              0                      0      1
# 4              0                      0      1

# %% [markdown]
# ###Matriz de correlação das características selecionadas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crie o mapa de correlação
correlation = abs(new_df.drop([tutor],axis=1)).corr()

# Plote o mapa de correlação
plt.figure(figsize=(10, 10))
sns.heatmap(correlation, annot=True, cmap="Blues")
plt.title("Mapa de correlação das melhores características")
plt.savefig( "mapa_correlacao-attrition-melhores.pdf", format="pdf", bbox_inches="tight")
plt.show()

# Salve o mapa de correlação em PDF

# %%
import numpy as np

# %%
upper_corr_mat = correlation.where(
    np.triu(np.ones(correlation.shape), k=1).astype(np.bool))
unique_corr_pairs = upper_corr_mat.unstack().dropna()
sorted_mat = unique_corr_pairs.sort_values()
print(sorted_mat)
# Out:
# number_project         satisfaction_level      -0.142970
# time_spend_company     satisfaction_level      -0.100866
# department             promotion_last_5years   -0.027336
# average_montly_hours   satisfaction_level      -0.020048
# department             time_spend_company      -0.018010
# work_accident          average_montly_hours    -0.010143
# promotion_last_5years  last_evaluation         -0.008684
# work_accident          last_evaluation         -0.007104
# promotion_last_5years  number_project          -0.006064
# work_accident          number_project          -0.004741
# promotion_last_5years  average_montly_hours    -0.003544
# salary                 time_spend_company      -0.003086
#                        work_accident           -0.002506
#                        promotion_last_5years   -0.001318
#                        department               0.000685
# work_accident          time_spend_company       0.002120
# ...

# %% [markdown]
# ###Histograma com as características selecionadas pelo SelectKBest

# %%
new_df.hist(figsize=(9,7))
plt.savefig( "histograma.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ##Redução de dimensionalidade

# %% [markdown]
# ###PCA

# %%
from sklearn.decomposition import PCA
Xp = PCA(n_components=2).fit_transform(df.drop([tutor],axis=1).values)
y = df[tutor].values
sns.scatterplot(x=Xp[:,0],y=Xp[:,1],hue=y)
plt.savefig( "pca.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ###TSNE

# %% [markdown]
# https://www.datacamp.com/tutorial/introduction-t-sne

# %%
from sklearn.manifold import TSNE
import plotly.express as px

tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(df.drop([tutor],axis=1).values)
tsne.kl_divergence_
# Out:
# 1.0863525867462158

# %%
fig = px.scatter(x=X_tsne[:, 0], y=X_tsne[:, 1], color=y)
fig.update_layout(
    title="t-SNE visualization of Custom Classification dataset",
    xaxis_title="First t-SNE",
    yaxis_title="Second t-SNE",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install -U kaleido
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 13.7 MB/s eta 0:00:00
# ...

# %%
fig.write_image('tsne_attrition.pdf')

# %% [markdown]
# # Detector de Anomalias

# %%
import time

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.datasets import make_moons, make_blobs
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.linear_model import SGDOneClassSVM
from sklearn.kernel_approximation import Nystroem
from sklearn.pipeline import make_pipeline
from sklearn import metrics

turnovers = df[tutor].value_counts()[1] # contagens de valores únicos de classe
# outliers_fraction -> quanto turnovers ocorreu no conjunto total
outliers_fraction = turnovers/len(df)
if outliers_fraction > 0.50:
  outliers_fraction=round(outliers_fraction,1)


X = df.drop(labels=[tutor],axis=1).values
y_true = df[tutor].values

detectores = [
      EllipticEnvelope(contamination=outliers_fraction,random_state=42),
      EllipticEnvelope(contamination=outliers_fraction,assume_centered=True,random_state=42),
      EllipticEnvelope(contamination=outliers_fraction,store_precision=False,random_state=42),
      svm.OneClassSVM(nu=outliers_fraction, kernel='rbf', gamma='auto'),
      svm.OneClassSVM(nu=outliers_fraction, kernel='sigmoid', gamma='auto'),
      svm.OneClassSVM(nu=outliers_fraction, kernel='poly', gamma='auto'),
      make_pipeline(Nystroem(gamma=0.1, random_state=42, n_components=20),
            SGDOneClassSVM(nu=outliers_fraction,shuffle=True,fit_intercept=True,random_state=42,tol=1e-6)),
      make_pipeline(Nystroem(gamma=0.1, random_state=42, n_components=100),
            SGDOneClassSVM(nu=outliers_fraction,shuffle=True,fit_intercept=True,random_state=42,tol=1e-6)),
      make_pipeline(Nystroem(gamma=0.1, random_state=42, n_components=20),
            SGDOneClassSVM(nu=outliers_fraction,shuffle=True,fit_intercept=True,random_state=42,tol=1e-2)),
      make_pipeline(Nystroem(gamma=0.1, random_state=42, n_components=100),
            SGDOneClassSVM(nu=outliers_fraction,shuffle=True,fit_intercept=True,random_state=42,tol=1e-2)),
      IsolationForest(contamination=outliers_fraction, random_state=42),
      IsolationForest(contamination=outliers_fraction, random_state=42, bootstrap=True),
      IsolationForest(contamination=outliers_fraction, random_state=42, n_estimators=20),
      IsolationForest(contamination=outliers_fraction, random_state=42, n_estimators=20, bootstrap=True),
      LocalOutlierFactor(n_neighbors=20, contamination=outliers_fraction,novelty=True),
      LocalOutlierFactor(n_neighbors=60, contamination=outliers_fraction,novelty=True),
      LocalOutlierFactor(n_neighbors=20, metric='braycurtis', contamination=outliers_fraction,novelty=True),
      LocalOutlierFactor(n_neighbors=60, metric='braycurtis', contamination=outliers_fraction,novelty=True),
      LocalOutlierFactor(n_neighbors=20, metric='jaccard', contamination=outliers_fraction,novelty=True),
      LocalOutlierFactor(n_neighbors=60, metric='jaccard', contamination=outliers_fraction,novelty=True),
]

res = []
for id, det in enumerate(detectores):
  t0 = time.time()
  y_ano = det.fit(X).predict(X)
  t1 = time.time()

  # ajuste da saída do detector -1 anomalia, +1 normal
  # -1 >> 1 e +1 >> 0
  y_pred = -(y_ano - 1) // 2

  f1w = metrics.f1_score(y_true, y_pred, average='weighted')
  bac = metrics.balanced_accuracy_score(y_true, y_pred)
  prw = metrics.precision_score(y_true,y_pred, average='weighted')
  rew = metrics.recall_score(y_true, y_pred, average='weighted')





  dn = {'id':id,
        'name': det.__class__.__name__,
        'time':round(t1-t0,3),
        'f1': round(f1w,5),
        'balanced accuracy': round(bac,5),
        'precision weighted': round(prw,5),
        'recall weighted': round(rew, 5)}
  res.append(dn)
  print(dn)

resDF = pd.DataFrame(res)
resDF
# Out:
# {'id': 0, 'name': 'EllipticEnvelope', 'time': 3.641, 'f1': 0.66606, 'balanced accuracy': 0.5398, 'precision weighted': 0.66608, 'recall weighted': 0.66604}
# {'id': 1, 'name': 'EllipticEnvelope', 'time': 6.809, 'f1': 0.66144, 'balanced accuracy': 0.53341, 'precision weighted': 0.66144, 'recall weighted': 0.66144}
# {'id': 2, 'name': 'EllipticEnvelope', 'time': 4.177, 'f1': 0.66606, 'balanced accuracy': 0.5398, 'precision weighted': 0.66608, 'recall weighted': 0.66604}
# {'id': 3, 'name': 'OneClassSVM', 'time': 13.906, 'f1': 0.612, 'balanced accuracy': 0.46538, 'precision weighted': 0.61209, 'recall weighted': 0.61191}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
resDF.sort_values('balanced accuracy', ascending=False)
# Out:
#     id                name    time       f1  balanced accuracy  \
# 5    5         OneClassSVM   7.312  0.69443            0.57885
# 0    0    EllipticEnvelope   3.641  0.66606            0.53980
# 2    2    EllipticEnvelope   4.177  0.66606            0.53980
# 1    1    EllipticEnvelope   6.809  0.66144            0.53341
# 8    8            Pipeline   0.051  0.46811            0.50412
# 4    4         OneClassSVM   3.107  0.09157            0.50000
# 18  18  LocalOutlierFactor  16.781  0.65881            0.49959
# 19  19  LocalOutlierFactor  16.318  0.65693            0.49709
# 6    6            Pipeline   0.075  0.54789            0.48774
# 9    9            Pipeline   0.404  0.62464            0.48573
# 7    7            Pipeline   0.523  0.62648            0.48466
# 10  10     IsolationForest   1.061  0.62264            0.47993
# 3    3         OneClassSVM  13.906  0.61200            0.46538
# 15  15  LocalOutlierFactor   0.845  0.60916            0.45928
# ...

# %% [markdown]
# #Classificação

# %% [markdown]
# ## Balanceamento utilizando SMOTE

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
from matplotlib import pyplot
from numpy import where
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

# %%
smote = SMOTE()
X, y = smote.fit_resample(X, y)

# %%
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
 row_ix = where(y == label)[0]
 pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({1: 11428, 0: 11428})

# %% [markdown]
# ## Classificadores clássicos

# %%
# !pip install lightgbm

# %%
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import BernoulliNB, CategoricalNB, ComplementNB, MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier, NearestCentroid
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier, XGBRFClassifier
from lightgbm import DaskLGBMClassifier, LGBMClassifier
import warnings
from tqdm.notebook import tqdm
warnings.filterwarnings('ignore')

tecnicas = [
  RidgeClassifier(random_state=42),
  LogisticRegression(random_state=42),
  DummyClassifier(random_state=42),
  LinearDiscriminantAnalysis(),
  QuadraticDiscriminantAnalysis(),
  AdaBoostClassifier(random_state=42),
  BaggingClassifier(random_state=42),
  ExtraTreesClassifier(random_state=42),
  GradientBoostingClassifier(random_state=42),
  RandomForestClassifier(random_state=42),
  HistGradientBoostingClassifier(random_state=42),
  BernoulliNB(),
  CategoricalNB(),
  ComplementNB(),
  MultinomialNB(),
  GaussianNB(),
  KNeighborsClassifier(),
  RadiusNeighborsClassifier(),
  NearestCentroid(),
  MLPClassifier(random_state=42),
  LinearSVC(),
  NuSVC(),
  SVC(),
  DecisionTreeClassifier(random_state=42, max_depth=5),
  ExtraTreeClassifier(random_state=42, max_depth=15),
  XGBClassifier(objective="binary:logistic", random_state=42),
  XGBRFClassifier(n_estimators=100, subsample=0.9),
  DaskLGBMClassifier(n_estimators=10, random_state=42),
  LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42),
  ]

metricas = ['balanced_accuracy','precision_weighted','recall_weighted','f1_weighted']

r=[]
for t in tqdm(tecnicas):
  nome = t.__class__.__name__
  cv = GridSearchCV(t,{},cv=4,scoring=metricas,refit=False)
  dn = {'nome':nome}
  try:
    cv.fit(X,y)
    dn['fitTime'] = round(cv.cv_results_['std_fit_time'][0],5)
    for m in metricas:
      dn[m] = round(cv.cv_results_['mean_test_' + m][0],5)
  except Exception as e:
    print(nome,str(e))
  r.append(dn)

warnings.filterwarnings('default')

df_res = pd.DataFrame(r)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# DaskLGBMClassifier
# All the 4 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/lightgbm/dask.py", line 1202, in fit
#     self._lgb_dask_fit(
#   File "/usr/local/lib/python3.10/dist-packages/lightgbm/dask.py", line 1083, in _lgb_dask_fit
#     client=_get_dask_client(self.client),
#   File "/usr/local/lib/python3.10/dist-packages/lightgbm/dask.py", line 85, in _get_dask_client
#     return default_client()
# ...

# %%
df_res.sort_values('balanced_accuracy',ascending=False)
# Out:
#                               nome  fitTime  balanced_accuracy  \
# 25                   XGBClassifier  0.35739            0.58791
# 9           RandomForestClassifier  0.00479            0.58717
# 28                  LGBMClassifier  0.02043            0.57564
# 10  HistGradientBoostingClassifier  0.00872            0.57555
# 7             ExtraTreesClassifier  0.00772            0.56847
# 21                           NuSVC  0.00685            0.56832
# 26                 XGBRFClassifier  0.03350            0.56631
# 6                BaggingClassifier  0.04708            0.56416
# 5               AdaBoostClassifier  0.00414            0.55883
# 8       GradientBoostingClassifier  0.00386            0.55876
# 19                   MLPClassifier  0.10796            0.54740
# 15                      GaussianNB  0.00007            0.54292
# 23          DecisionTreeClassifier  0.00161            0.53035
# 4    QuadraticDiscriminantAnalysis  0.01171            0.53029
# ...

# %% [markdown]
# ## Stacking Classifier

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingClassifier.html
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import BernoulliNB, CategoricalNB, ComplementNB, MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier, NearestCentroid
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from lightgbm import DaskLGBMClassifier, LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import StackingClassifier
import random
from copy import deepcopy
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')

random.seed=42

listas = [
  RidgeClassifier(random_state=42),
  LogisticRegression(random_state=42),
  LinearDiscriminantAnalysis(),
  QuadraticDiscriminantAnalysis(),
  BernoulliNB(),
  GaussianNB(),
  KNeighborsClassifier(),
  MLPClassifier(random_state=42 ),
  LinearSVC(),
  NuSVC(),
  SVC(),
  DecisionTreeClassifier(random_state=42, max_depth=5),
  ExtraTreeClassifier(random_state=42, max_depth=15),
  XGBClassifier(objective="binary:logistic", random_state=42),
  XGBRFClassifier(n_estimators=100, subsample=0.9),
  DaskLGBMClassifier(n_estimators=10),
  LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42),
]

metricas = ['balanced_accuracy','precision_weighted','recall_weighted','f1_weighted']

def pegaItem():
  return deepcopy(listas[random.randint(0,len(listas)-1)])

sc_res = []
for i in tqdm(range(20)):

  estimadores = []
  for j in range(random.randint(2,5)):
    estimadores.append((f'clf_{j}',pegaItem()))
  est_nomes = ','.join([y.__class__.__name__ for x, y in estimadores])

  estimador_saida = pegaItem()

  sc = StackingClassifier(estimadores,estimador_saida,cv=5)

  dn = {
      'id':i,
      'estimadores': est_nomes,
      'saida': estimador_saida.__class__.__name__,
  }

  cv = GridSearchCV(sc,{},cv=4,scoring=metricas,refit=False)
  try:
    cv.fit(X,y)
  except Exception as e:
    sc_res.append(dn)
    print('ERRO:',est_nomes,estimador_saida,str(e))
    continue

  dn['fitTime'] = round(cv.cv_results_['std_fit_time'][0],5)
  for m in metricas:
    dn[m] = round(cv.cv_results_['mean_test_' + m][0],5)

  sc_res.append(dn)

warnings.filterwarnings('default')

pd.DataFrame(sc_res)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ERRO: DecisionTreeClassifier,DaskLGBMClassifier,LGBMClassifier,SVC LGBMClassifier(learning_rate=0.09, max_depth=-5, random_state=42)
# All the 4 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_stacking.py", line 660, in fit
#     return super().fit(X, y_encoded, sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_stacking.py", line 209, in fit
# ...

# %%
pd.DataFrame(sc_res).sort_values('balanced_accuracy',ascending=False)
# Out:
#     id                                        estimadores  \
# 13  13  SVC,KNeighborsClassifier,ExtraTreeClassifier,X...
# 4    4          XGBClassifier,MLPClassifier,MLPClassifier
# 12  12  LGBMClassifier,LGBMClassifier,LGBMClassifier,K...
# 1    1      XGBRFClassifier,XGBClassifier,RidgeClassifier
# 14  14  XGBClassifier,RidgeClassifier,KNeighborsClassi...
# 9    9  LinearDiscriminantAnalysis,LGBMClassifier,SVC,...
# 15  15           BernoulliNB,DecisionTreeClassifier,NuSVC
# 17  17                        BernoulliNB,XGBRFClassifier
# 7    7                      ExtraTreeClassifier,LinearSVC
# 19  19            KNeighborsClassifier,LogisticRegression
# 10  10                           NuSVC,LogisticRegression
# 18  18  SVC,LinearDiscriminantAnalysis,LogisticRegression
# 0    0  DecisionTreeClassifier,DaskLGBMClassifier,LGBM...
# 2    2       DaskLGBMClassifier,MLPClassifier,BernoulliNB
# 3    3  QuadraticDiscriminantAnalysis,MLPClassifier,Li...
# ...

# %% [markdown]
# ## Voting Classifier

# %%
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import BernoulliNB, CategoricalNB, ComplementNB, MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier, NearestCentroid
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from lightgbm import DaskLGBMClassifier, LGBMClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import StackingClassifier
import random
from copy import deepcopy
from tqdm.notebook import tqdm
import warnings

# %%
# não funcionou bem...
from sklearn.ensemble import VotingClassifier
import random
from copy import deepcopy
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')

metricas = ['balanced_accuracy','precision_weighted','recall_weighted','f1_weighted']

random.seed=42

listas = [
  RidgeClassifier(random_state=42),
  LogisticRegression(random_state=42),
  LinearDiscriminantAnalysis(),
  QuadraticDiscriminantAnalysis(),
  BernoulliNB(),
  GaussianNB(),
  KNeighborsClassifier(),
  MLPClassifier(random_state=42),
  LinearSVC(),
  NuSVC(),
  SVC(),
  DecisionTreeClassifier(random_state=42, max_depth=5),
  ExtraTreeClassifier(random_state=42, max_depth=15),
  XGBClassifier(objective="binary:logistic", random_state=42),
  XGBRFClassifier(n_estimators=100, subsample=0.9),
  DaskLGBMClassifier(n_estimators=10),
  LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42, force_row_wise=True),
]

def pegaItem():
  return deepcopy(listas[random.randint(0,len(listas)-1)])

vc_res = []
for i in tqdm(range(20)):

  estimadores = []
  for j in range(random.randint(2,5)):
    estimadores.append((f'clf_{j}',pegaItem()))
  est_nomes = ','.join([y.__class__.__name__ for x, y in estimadores])

  vc = VotingClassifier(estimadores,voting='hard')

  dn = {
      'id':i,
      'estimadores': est_nomes,
  }

  cv = GridSearchCV(vc,{},cv=4,scoring=metricas,refit=False)
  try:
    cv.fit(X,y)
  except Exception as e:
    vc_res.append(dn)
    print('ERRO:',est_nomes,str(e))
    continue

  dn['fitTime'] = round(cv.cv_results_['std_fit_time'][0],5)
  for m in metricas:
    dn[m] = round(cv.cv_results_['mean_test_' + m][0],5)

  vc_res.append(dn)

warnings.filterwarnings('default')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ERRO: ExtraTreeClassifier,DaskLGBMClassifier,QuadraticDiscriminantAnalysis,XGBClassifier,BernoulliNB
# All the 4 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_voting.py", line 346, in fit
#     return super().fit(X, transformed_y, sample_weight)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_voting.py", line 81, in fit
#     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
# ...

# %%
pd.DataFrame(vc_res).sort_values('balanced_accuracy',ascending=False)
# Out:
#     id                                        estimadores   fitTime  \
# 14  14  XGBRFClassifier,LinearSVC,QuadraticDiscriminan...   1.32898
# 10  10  LGBMClassifier,LinearDiscriminantAnalysis,XGBC...   0.02097
# 7    7  LogisticRegression,MLPClassifier,XGBClassifier...  20.31532
# 1    1  NuSVC,XGBClassifier,LinearDiscriminantAnalysis...  43.15471
# 4    4  KNeighborsClassifier,LinearDiscriminantAnalysi...   0.12197
# 5    5                          LinearSVC,XGBRFClassifier   2.96463
# 18  18  DecisionTreeClassifier,LinearDiscriminantAnaly...   0.02259
# 6    6  GaussianNB,MLPClassifier,SVC,KNeighborsClassifier  11.96697
# 3    3  LogisticRegression,LogisticRegression,ExtraTre...   0.05153
# 9    9                          BernoulliNB,MLPClassifier   9.84513
# 12  12  DecisionTreeClassifier,LinearSVC,LogisticRegre...   2.65542
# 13  13  NuSVC,RidgeClassifier,DecisionTreeClassifier,L...  28.49478
# 15  15                                LinearSVC,LinearSVC   1.84821
# ...

# %% [markdown]
# #TPOT
#
# https://epistasislab.github.io/tpot/

# %%
# !pip install tpot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 9.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=33c4c36e65740f8f06eb9b208573221d502dc6444fb09daad3392ac877df5500
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# ...

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  work_accident  class  \
# 0                       157                   3              0      1
# 1                       262                   6              0      1
# ...

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
max_features = ['auto', 'sqrt','log2']
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
min_samples_split = [2, 5, 10,14]
min_samples_leaf = [1, 2, 4,6,8]
param = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(param)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
from tpot import TPOTClassifier

# %%
tpot_classifier = TPOTClassifier(generations= 5, population_size= 24, offspring_size= 12, random_state=42,
                                 verbosity= 2, early_stop= 12, template='Classifier-Classifier-Classifier',
                                 cv = 4)
tpot_classifier.fit(X,y)
# Out:
# Optimization Progress:   0%|          | 0/84 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9844679733986699
#
# Generation 2 - Current best internal CV score: 0.9844679733986699
#
# Generation 3 - Current best internal CV score: 0.9878368918445923
#
# Generation 4 - Current best internal CV score: 0.9878368918445923
#
# Generation 5 - Current best internal CV score: 0.9878368918445923
#
# Best pipeline: ExtraTreesClassifier(XGBClassifier(ExtraTreesClassifier(input_matrix, bootstrap=False, criterion=gini, max_features=0.7500000000000001, min_samples_leaf=2, min_samples_split=13, n_estimators=100), learning_rate=0.01, max_depth=4, min_child_weight=20, n_estimators=100, n_jobs=1, subsample=0.6000000000000001, verbosity=0), bootstrap=False, criterion=entropy, max_features=0.3, min_samples_leaf=5, min_samples_split=5, n_estimators=100)
# TPOTClassifier(cv=4, early_stop=12, generations=5, offspring_size=12,
#                population_size=24, random_state=42,
# ...

# %%
scores = tpot_classifier.score(X, y)
print(scores)
# Out:
# 0.8169877408056042

# %% [markdown]
# Resultados das métricas com o TPOT

# %%
from sklearn.metrics import SCORERS
best_pipeline = tpot_classifier.fitted_pipeline_
# f1_weighted
holdout_score_f1w = SCORERS['f1_weighted'](
                          best_pipeline,
                          X,
                          y
                      )
# balanced_accuracy
holdout_score_ba = SCORERS['balanced_accuracy'](
                          best_pipeline,
                          X,
                          y
                      )

# recall_weighted
holdout_score_rw = SCORERS['recall_weighted'](
                          best_pipeline,
                          X,
                          y
                      )
# precision weighted
holdout_score_pw = SCORERS['precision_weighted'](
                          best_pipeline,
                          X,
                          y
                      )

# %%
print("\nBalanced Accuracy: ", round(holdout_score_ba,6),"\nPrecision weighted: ",round(holdout_score_pw,6),  "\nRecall weighted: ", round(holdout_score_rw,6), "\nF1 weighted: ", round(holdout_score_f1w,6))
# Out:
# Balanced Accuracy:  0.816988
# Precision weighted:  0.817503
# Recall weighted:  0.816988
# F1 weighted:  0.816913

# %%
from sklearn.metrics import SCORERS
best_pipeline = tpot_classifier.fitted_pipeline_
# f1_weighted
holdout_score_f1w = SCORERS['f1'](
                          best_pipeline,
                          X,
                          y
                      )
# balanced_accuracy
holdout_score_ba = SCORERS['accuracy'](
                          best_pipeline,
                          X,
                          y
                      )

# recall_weighted
holdout_score_rw = SCORERS['recall'](
                          best_pipeline,
                          X,
                          y
                      )
# precision weighted
holdout_score_pw = SCORERS['precision'](
                          best_pipeline,
                          X,
                          y
                      )

# %%
print("Accuracy: ", round(holdout_score_ba,6),"\nPrecision: ",round(holdout_score_pw,6),  "\nRecall: ", round(holdout_score_rw,6), "\nF1: ", round(holdout_score_f1w,6))
# Out:
# Accuracy:  0.99945
# Precision:  0.999149
# Recall:  0.999751
# F1:  0.99945

# %%
tpot_classifier.export('tpot_exported_pipeline.py')
